# %%
#| hide
from mytestrepo.bore import *

# %% [markdown]
# # mytestrepo
#
# > testing solevit nbdev repo

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install mytestrepo in Development mode

# %% [markdown]
# ```sh
# # make sure mytestrepo package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to mytestrepo
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/akrishnamo/mytestrepo.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c akrishnamo mytestrepo
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install mytestrepo
# ```
#
#
# [repo]: https://github.com/akrishnamo/mytestrepo
# [docs]: https://akrishnamo.github.io/mytestrepo/
# [pypi]: https://pypi.org/project/mytestrepo/
# [conda]: https://anaconda.org/akrishnamo/mytestrepo

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/akrishnamo/mytestrepo
# [docs]: https://akrishnamo.github.io/mytestrepo/
# [pypi]: https://pypi.org/project/mytestrepo/
# [conda]: https://anaconda.org/akrishnamo/mytestrepo

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
foo(3)
# Out:
# 3
